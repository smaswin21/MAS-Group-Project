# %% [markdown]
# ### 1. Installation & imports of all the necessary libraries.

# %%
# In case needed, please uncomment and run the code:
# %pip install --upgrade mesa networkx pandas matplotlib

import random, math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import networkx as nx

import mesa
from mesa import Model, Agent
from mesa.space import MultiGrid
from mesa.datacollection import DataCollector

print("Mesa version:", mesa.__version__)  # should be 3.x
# Out:
# Mesa version: 3.3.0

# %% [markdown]
# ### 2. Utilities and Config
#
# + We keep the skills bounded and have our constants here.

# %%
def bound(x, lower=0.0, higher=100.0):
    return max(lower, min(x, higher))

# Defaults for the model to experiment: 

DEFAULT_ATTENDANCE_PROBABILITY = 0.75
DEFAULT_CLASS_MINUTES = [45, 60, 75, 90]

# %% [markdown]
# ### 3. Agents: Place, Teacher, Student
